# %%
import pandas as pd
import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt 
import matplotlib
from random import randint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel("/content/drive/MyDrive/GCCR_SlackAPI/Dataset/UserNameCountry_GCChemosensoryRSlack_output_anonymised.xlsx")
df['Date'] =  pd.to_datetime(df['Date'])

years=list(pd.DatetimeIndex(df['Date']).year)
months=list(pd.DatetimeIndex(df['Date']).month)

months_new=[]
for i in range(df.shape[0]):
  if years[i]==2020:
    months_new.append(months[i]-2)
  elif years[i]==2021:
    months_new.append(months[i]+10)
  elif years[i]==2022:
    months_new.append(23)
df['Month_new']=months_new

# %%
month_count = df['Month_new'].value_counts()

month_count = df['Month_new'].value_counts()
month_count_values = df['Month_new'].value_counts().keys().tolist()
month_count_counts = df['Month_new'].value_counts().tolist()

month_count_counts_sort = [x for _,x in sorted(zip(month_count_values,month_count_counts))]
month_count_values_sort=month_count_values.copy()
month_count_values_sort.sort()

month_count_values_sort[0] = 'March 2020'
month_count_values_sort[1] = 'April 2020' 
month_count_values_sort[2] = 'May 2020' 
month_count_values_sort[3] = 'June 2020' 
month_count_values_sort[4] = 'July 2020' 
month_count_values_sort[5] = 'August 2020' 
month_count_values_sort[6] = 'September 2020' 
month_count_values_sort[7] = 'October 2020' 
month_count_values_sort[8] = 'November 2020' 
month_count_values_sort[9] = 'December 2020'
month_count_values_sort[10] = 'January 2021'
month_count_values_sort[11] = 'Febuary 2021'
month_count_values_sort[12] = 'March 2021'
month_count_values_sort[13] = 'April 2021' 
month_count_values_sort[14] = 'May 2021' 
month_count_values_sort[15] = 'June 2021' 
month_count_values_sort[16] = 'July 2021' 
month_count_values_sort[17] = 'August 2021' 
month_count_values_sort[18] = 'September 2021' 
month_count_values_sort[19] = 'October 2021' 
month_count_values_sort[20] = 'November 2021' 
month_count_values_sort[21] = 'December 2021' 
month_count_values_sort[22] = 'January 2022' 

m_unique=[]
for m in range(1,24):
    month_df = df[df['Month_new'] == m]
    monthuniqueusers = month_df['id'].value_counts()
    m_unique.append(len(monthuniqueusers))
m_unique= np.array(m_unique)

#plt.title('Month v/s Active Users', fontsize="30")
plt.xlabel('Month',fontsize="22")
plt.ylabel('Active Users',fontsize="22")
###### Important ==>

colors = cm.viridis(m_unique / float(max(m_unique)))


plt.bar(month_count_values_sort,m_unique,color=colors)
plt.xticks(rotation = 90)
#plt.grid()
matplotlib.rcParams['figure.figsize'] = [20,5]
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
matplotlib.rcParams['figure.figsize'] = [20,5]
plt.savefig('/content/drive/MyDrive/GCCR_SlackAPI/Figures/API-A_new.png',dpi= 300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt 
import matplotlib

#plt.title('Quarter v/s Active Users: Q1 Contains only March' , fontsize="30")
plt.xlabel('Quarter',fontsize="22")
plt.ylabel('Active Users',fontsize="22")
y = np.array([348, 271+199+155, 152+92+70, 85+92+77, 571+97+83, 75+64+59, 67+61+52, 32+33+32, 24])
colors = cm.viridis(y / float(max(y)))

###### Important ==>
plt.bar(['Q1 2020','Q2 2020','Q3 2020','Q4 2020','Q1 2021','Q2 2021','Q3 2021','Q4 2021','Q1 2022'],y, color = colors)
plt.xticks(rotation = 90)
#plt.grid()
matplotlib.rcParams['figure.figsize'] = [20,5]
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig('/content/drive/MyDrive/GCCR_SlackAPI/Figures/API-B_new.png',dpi= 300, bbox_inches='tight')
plt.show()

# %%
m = list(range(1,24))

monthuniqueChannel = df['Country'].value_counts()
Country = monthuniqueChannel.keys().tolist()

countryseries =  pd.DataFrame(columns = Country)
countryseries = countryseries.assign(id=m)
countryseries.set_index('id', inplace=True)
#userseries.assign(user=unique_user)

for m in Country:
    count = df[df['Country'] == m]
    for t in range(1,24):
        count2 = count[count['Month_new'] == t]
        countryseries.at[t,m] = len(count2)
        
countryseries['Month'] = countryseries.index

countryseries['Month'].replace(1,'March 2020',inplace=True)
countryseries['Month'].replace(2,'April 2020',inplace=True)
countryseries['Month'].replace(3,'May 2020',inplace=True)
countryseries['Month'].replace(4,'June 2020',inplace=True)
countryseries['Month'].replace(5,'July 2020',inplace=True)
countryseries['Month'].replace(6,'August 2020',inplace=True)
countryseries['Month'].replace(7,'September 2020',inplace=True)
countryseries['Month'].replace(8,'October 2020',inplace=True)
countryseries['Month'].replace(9,'November 2020',inplace=True)
countryseries['Month'].replace(10,'December 2020',inplace=True)
countryseries['Month'].replace(11,'January 2021',inplace=True)
countryseries['Month'].replace(12,'Febuary 2021',inplace=True)
countryseries['Month'].replace(13,'March 2021',inplace=True)
countryseries['Month'].replace(14,'April 2021',inplace=True)
countryseries['Month'].replace(15,'May 2021',inplace=True)
countryseries['Month'].replace(16,'June 2021',inplace=True)
countryseries['Month'].replace(17,'July 2021',inplace=True)
countryseries['Month'].replace(18,'August 2021',inplace=True)
countryseries['Month'].replace(19,'September 2021',inplace=True)
countryseries['Month'].replace(20,'October 2021',inplace=True)
countryseries['Month'].replace(21,'November 2021',inplace=True)
countryseries['Month'].replace(22,'December 2021',inplace=True)
countryseries['Month'].replace(23,'January 2022',inplace=True)

import matplotlib.pyplot as plt 
import matplotlib
from random import randint 

colors=cm.viridis.colors
markers= ['.', '*', 'd', '<', '>', 's', 'o', '|', 'P', 'v','h']
matplotlib.rcParams['figure.figsize'] = [20,5]
i=0
j=0
for country_name in Country[:10]:
    #print(channel_name)
    print(i, colors[i])
    plt.plot(countryseries['Month'], countryseries[country_name],label=country_name, color=colors[i], 
             marker= markers[j])
    i=i+27
    j=j+1
    #y = countryseries[country_name]
    #colors = cm.viridis(y / float(max(y)))
    #plt.plot(countryseries['Month'], y,label=country_name,color=colors )

#plt.title('Timeseries', fontsize="35")
plt.xlabel('Month',fontsize=22)
plt.ylabel('Activity',fontsize=22)    

    
plt.legend()
#plt.grid()

plt.xticks(fontsize=20)
plt.xticks(rotation=90)
plt.yticks(fontsize=20)
plt.legend(fontsize=12)
plt.savefig('/content/drive/MyDrive/GCCR_SlackAPI/Figures/API-C_new.png',dpi= 300, bbox_inches='tight')
plt.show()
# Out:
# 0 [0.267004, 0.004874, 0.329415]
# 27 [0.281887, 0.150881, 0.465405]
# 54 [0.248629, 0.278775, 0.534556]
# 81 [0.197636, 0.391528, 0.554969]
# 108 [0.154815, 0.493313, 0.55784]
# 135 [0.121148, 0.592739, 0.544641]
# 162 [0.166383, 0.690856, 0.496502]
# 189 [0.344074, 0.780029, 0.397381]
# 216 [0.595839, 0.848717, 0.243329]
# 243 [0.876168, 0.891125, 0.09525]

# %%
country_count = df['Country'].value_counts()
country_count_values = df['Country'].value_counts().keys().tolist()
country_count_counts = df['Country'].value_counts().tolist()

d=dict()
for i in range(len(country_count_values)):
    
    if country_count_values[i]  in d:
        d[country_count_values[i]] += country_count_counts[i]
        
    else:
        d[country_count_values[i]] = country_count_counts[i]

sorted_x = sorted(d.items(), key=lambda kv: kv[1], reverse = True)
Country = []
Number= []
for i in sorted_x:
    Country.append(i[0])
    Number.append(i[1])

#plt.title('Country v/s Activity', fontsize="30")
plt.xlabel('Country',fontsize=22)
plt.ylabel('Activity',fontsize=22)
my_cmap = plt.get_cmap("viridis")
###### Important ==>
Number = np.array(Number)
colors= cm.viridis(Number/ float(max(Number)))
#plt.bar(Country, Number, color = 'darkred', edgecolor = 'red' )
plt.bar(Country, Number, color=colors )
plt.xticks(rotation = 90)
#plt.grid()
matplotlib.rcParams['figure.figsize'] = [10,5]
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig('/content/drive/MyDrive/GCCR_SlackAPI/Figures/API-D_new.png',dpi= 300, bbox_inches='tight')
plt.show()

# %%
country_count = df['Continent'].value_counts()
country_count =country_count.drop('Indiana')
country_count_values = country_count.keys().tolist()
country_count_counts = country_count.tolist()


#plt.title('Continent v/s Activity', fontsize="30")
plt.xlabel('Continent',fontsize="30")
plt.ylabel('Activity',fontsize="30")
###### Important ==>
#plt.bar(country_count_values,country_count_counts, color = 'darkred', edgecolor = 'red')

country_count_counts = np.array(country_count_counts)
colors= cm.viridis(country_count_counts/ float(max(country_count_counts)))

plt.bar(country_count_values,country_count_counts, color=colors)

plt.xticks(rotation = 90)
#plt.grid()
matplotlib.rcParams['figure.figsize'] = [10,5]
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.savefig('/content/drive/MyDrive/GCCR_SlackAPI/Figures/API-F_new.png',dpi= 300, bbox_inches='tight')
plt.show()

# %%
monthwise=[[] for i in range(23)]
for m in range(1,24):
    month_df = df[df['Month_new'] == m]
    monthuniqueChannel = month_df['Channel'].value_counts()
    for i in range(10):
      try:
        print(monthuniqueChannel.keys()[i],'('+str(monthuniqueChannel[i])+')')
        monthwise[m-1].append(monthuniqueChannel.keys()[i]+' ('+str(monthuniqueChannel[i])+')')
      except:
        monthwise[m-1].append('-')
        
    print()

quaterwise=[[] for i in range(9)]
month_df = df[df['Month_new'] == 1]
monthuniqueChannel = month_df['Channel'].value_counts()
for i in range(10):
      try:
        print(monthuniqueChannel.keys()[i],'('+str(monthuniqueChannel[i])+')')
        quaterwise[0].append(monthuniqueChannel.keys()[i]+' ('+str(monthuniqueChannel[i])+')')
      except:
        quaterwise[0].append('-')

print()
        
month_df = df[(df['Month_new'] > 1) & (df['Month_new'] <=4) ]
monthuniqueChannel = month_df['Channel'].value_counts()
for i in range(10):
      try:
        print(monthuniqueChannel.keys()[i],'('+str(monthuniqueChannel[i])+')')
        quaterwise[1].append(monthuniqueChannel.keys()[i]+' ('+str(monthuniqueChannel[i])+')')
      except:
        quaterwise[1].append('-')

print()
        
month_df = df[(df['Month_new'] > 4) & (df['Month_new'] <=7) ]
monthuniqueChannel = month_df['Channel'].value_counts()
for i in range(10):
      try:
        print(monthuniqueChannel.keys()[i],'('+str(monthuniqueChannel[i])+')')
        quaterwise[2].append(monthuniqueChannel.keys()[i]+' ('+str(monthuniqueChannel[i])+')')
      except:
        quaterwise[2].append('-')

print()
        
month_df = df[(df['Month_new'] > 7) & (df['Month_new'] <=10) ]
monthuniqueChannel = month_df['Channel'].value_counts()
for i in range(10):
      try:
        print(monthuniqueChannel.keys()[i],'('+str(monthuniqueChannel[i])+')')
        quaterwise[3].append(monthuniqueChannel.keys()[i]+' ('+str(monthuniqueChannel[i])+')')
      except:
        quaterwise[3].append('-')

print()
        
month_df = df[(df['Month_new'] > 10) & (df['Month_new'] <=13) ]
monthuniqueChannel = month_df['Channel'].value_counts()
for i in range(10):
      try:
        print(monthuniqueChannel.keys()[i],'('+str(monthuniqueChannel[i])+')')
        quaterwise[4].append(monthuniqueChannel.keys()[i]+' ('+str(monthuniqueChannel[i])+')')
      except:
        quaterwise[4].append('-')

print()
        
month_df = df[(df['Month_new'] > 13) & (df['Month_new'] <=16) ]
monthuniqueChannel = month_df['Channel'].value_counts()
for i in range(10):
      try:
        print(monthuniqueChannel.keys()[i],'('+str(monthuniqueChannel[i])+')')
        quaterwise[5].append(monthuniqueChannel.keys()[i]+' ('+str(monthuniqueChannel[i])+')')
      except:
        quaterwise[5].append('-')

print()
        
month_df = df[(df['Month_new'] > 16) & (df['Month_new'] <=19) ]
monthuniqueChannel = month_df['Channel'].value_counts()
for i in range(10):
      try:
        print(monthuniqueChannel.keys()[i],'('+str(monthuniqueChannel[i])+')')
        quaterwise[6].append(monthuniqueChannel.keys()[i]+' ('+str(monthuniqueChannel[i])+')')
      except:
        quaterwise[6].append('-')

print()
        
month_df = df[(df['Month_new'] > 19) & (df['Month_new'] <=22) ]
monthuniqueChannel = month_df['Channel'].value_counts()
for i in range(10):
      try:
        print(monthuniqueChannel.keys()[i],'('+str(monthuniqueChannel[i])+')')
        quaterwise[7].append(monthuniqueChannel.keys()[i]+' ('+str(monthuniqueChannel[i])+')')
      except:
        quaterwise[7].append('-')

print()

month_df = df[df['Month_new'] == 23]
monthuniqueChannel = month_df['Channel'].value_counts()
for i in range(10):
      try:
        print(monthuniqueChannel.keys()[i],'('+str(monthuniqueChannel[i])+')')
        quaterwise[8].append(monthuniqueChannel.keys()[i]+' ('+str(monthuniqueChannel[i])+')')
      except:
        quaterwise[8].append('-')

dfmonthwise=pd.DataFrame(zip(list(range(1,11)),monthwise[0],monthwise[1],monthwise[2],monthwise[3],monthwise[4],monthwise[5],monthwise[6],monthwise[7],monthwise[8],monthwise[9],monthwise[10],monthwise[11],monthwise[12],monthwise[13],monthwise[14],monthwise[15],monthwise[16],monthwise[17],monthwise[18],monthwise[19],monthwise[20],monthwise[21],monthwise[22]),columns=['Channel Position']+['March 2020','April 2020','May 2020','June 2020','July 2020','August 2020','September 2020','October 2020','November 2020','December 2020','January 2021','Febuary 2021','March 2021','April 2021','May 2021','June 2021','July 2021','August 2021','September 2021','October 2021','November 2021','December 2021','January 2022'])
dfquaterwise=pd.DataFrame(zip(list(range(1,11)),quaterwise[0],quaterwise[1],quaterwise[2],quaterwise[3],quaterwise[4],quaterwise[5],quaterwise[6],quaterwise[7],quaterwise[8]),columns=['Channel Position']+['Q1 2020','Q2 2020','Q3 2020','Q4 2020','Q1 2021','Q2 2021','Q3 2021','Q4 2021','Q1 2022'])

dfmonthwise.to_csv('/content/drive/MyDrive/GCCR_SlackAPI/Tables/month.csv')
dfquaterwise.to_csv('/content/drive/MyDrive/GCCR_SlackAPI/Tables/quater.csv')
# Out:
# agreement_sign (430)
# key_announcements (367)
# translation_offered (356)
# covid-19hometest (335)
# volunteers_wanted (325)
# covid-19-agenda (320)
# important_links (271)
# _indiaa (255)
# covid-19questionnaire (252)
# dailysummary-see-key_announcements (243)
#
# questionnaire-data-analysis (559)
# _indiaa (500)
# dailysummary-see-key_announcements (323)
# webpage (321)
# key_announcements (301)
# covid-19hometest (285)
# _netherlands (201)
# _argentina (182)
# _china (161)
# _italy (146)
#
# key_announcements (403)
# projectideas (220)
# _uk (203)
# _spanish_speaking_countries (162)
# _italy (151)
# basic-science (128)
# important_links (105)
# _indiaa (98)
# random (86)
# press_releases (76)
#
# eds002 (177)
# key_announcements (116)
# _italy (82)
# random (80)
# communication_volunteers (64)
# project_recovery (63)
# basic-science (60)
# webpage (47)
# project_age-and-smell (42)
# z_slack_admin (38)
#
# key_announcements (267)
# random (69)
# comm_social_media (67)
# ...
